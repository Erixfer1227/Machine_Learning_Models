# %% [markdown]
# __INSTALAR LIBRERIAS__

# %%
# !pip install pandas
# !pip install seaborn
# !pip install numpy
# !pip install scikit-learn

# %% [markdown]
# __IMPORTAR LIBRERIAS__

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# %% [markdown]
# __IMPORTAR DATASET__

# %%
df = pd.read_csv('/Users/erickfernandochaconflores/Downloads/dataset_Facebook.csv')

# %%
df.head()
# Out:
#    Page total likes    Type  Category  Post Month  Post Weekday  Post Hour
# 0            139441   Photo         2          12             4          3  \
# 1            139441  Status         2          12             3         10
# 2            139441   Photo         3          12             3          3
# 3            139441   Photo         2          12             2         10
# 4            139441   Photo         2          12             2          3
#
#    Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions
# 0   0.0                       2752                             5091  \
# 1   0.0                      10460                            19057
# 2   0.0                       2413                             4373
# 3   1.0                      50128                            87991
# 4   0.0                       7244                            13594
#
#    Lifetime Engaged Users  Lifetime Post Consumers
# ...

# %%
df.tail()
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour
# 495             85093  Photo         3           1             7          2  \
# 496             81370  Photo         2           1             5          8
# 497             81370  Photo         1           1             5          2
# 498             81370  Photo         3           1             4         11
# 499             81370  Photo         2           1             4          4
#
#      Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions
# 495   0.0                       4684                             7536  \
# 496   0.0                       3480                             6229
# 497   0.0                       3778                             7216
# 498   0.0                       4156                             7564
# 499   NaN                       4188                             7292
#
#      Lifetime Engaged Users  Lifetime Post Consumers
# ...

# %% [markdown]
# __VISUALIZACIÓN DE DATOS__

# %%
# Seaborn solo trabaja con dataframes, entonces voy hacer un dataframe unicamente con las variables que quisiera visualiar
df_nuevo = df[['Total Interactions', 'Post Weekday', 'like', 'Post Hour',]]

# %%
# Crear gráfica con Seaborn

grafica = sns.pairplot(df_nuevo, hue='Post Weekday', diag_kind='hist')

# Ahora creamos un ciclo for para que las gráficas se puedan visualizar mejor
for ax in g.axes.flat:
    plt.setp(ax.get_xticklabels(), rotation = 45)

#Donde:
#______
#hue = tonos, se escoge una variable de la que dependeran los tonos
#diag_kind = tipo de gráfico

sns.set_style('darkgrid')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[58], line 6
#       3 grafica = sns.pairplot(df_nuevo, hue='Post Weekday', diag_kind='hist')
#       5 # Ahora creamos un ciclo for para que las gráficas se puedan visualizar mejor
# ----> 6 for ax in g.axes.flat:
#       7     plt.setp(ax.get_xticklabels(), rotation = 45)
#       9 #Donde:
#      10 #______
#      11 #hue = tonos, se escoge una variable de la que dependeran los tonos
#      12 #diag_kind = tipo de gráfico
#
# NameError: name 'g' is not defined

# %% [markdown]
# __PREPROCESAMIENTO DE DATOS__

# %%
# Remplazar los nan con valores 0 en el dataset
df = df.replace (np.nan, "0")

# %%
# La función values devuelve una matriz NumPy que contiene los valores de la columna especificada. 
# Cada variable creada almacena los valores de la variable especificada, pero en forma de lista y de forma horizontal
share = df['share'].values
Post_Hour = df['Post Hour'].values
Post_Weekday = df['Post Weekday'].values
like = df['like'].values
Total_Interactions = df['Total Interactions'].values

# %% [markdown]
# __ARMANDO REGRESION LINEAL MULTIPLE__

# %%
# Definir variables X
X = np.array ([Post_Hour, Post_Weekday, Total_Interactions]).T
print(X)

#Donde:
# .T = Transponer matriz (Las columnas las pone como filas y viceversa)
# Out:
# [[  3   4 100]
#  [ 10   3 164]
#  [  3   3  80]
#  ...
#  [  2   5 115]
#  [ 11   4 136]
#  [  4   4 119]]

# %%
# Definir variables Y
Y = np.array ([like]).T
print (Y)
# Out:
# [[79.0]
#  [130.0]
#  [66.0]
#  [1572.0]
#  [325.0]
#  [152.0]
#  [249.0]
#  [325.0]
#  [161.0]
#  [113.0]
#  [233.0]
#  [88.0]
#  [90.0]
#  [137.0]
#  [577.0]
#  [86.0]
#  [40.0]
#  [678.0]
#  [54.0]
#  [34.0]
#  [66.0]
#  [0.0]
#  [16.0]
#  [72.0]
#  [99.0]
#  [88.0]
#  [412.0]
#  [100.0]
#  [523.0]
#  [143.0]
#  [107.0]
#  [27.0]
#  [155.0]
#  [98.0]
#  [56.0]
#  [172.0]
#  [96.0]
#  [76.0]
#  [227.0]
#  [44.0]
#  [216.0]
#  [187.0]
#  [26.0]
#  [29.0]
#  [47.0]
#  [57.0]
#  [174.0]
#  [18.0]
#  [77.0]
#  [12.0]
#  [48.0]
#  [285.0]
#  [202.0]
#  [64.0]
#  [66.0]
#  [65.0]
#  [164.0]
#  [40.0]
#  [76.0]
#  [139.0]
#  [101.0]
#  [144.0]
#  [179.0]
#  [219.0]
#  [60.0]
#  [77.0]
#  [48.0]
#  [697.0]
#  [53.0]
#  [84.0]
#  [146.0]
#  [449.0]
#  [226.0]
#  [172.0]
#  [99.0]
#  [411.0]
#  [0.0]
#  [85.0]
#  [56.0]
#  [29.0]
#  [86.0]
#  [370.0]
#  [190.0]
#  [101.0]
#  [99.0]
#  [140.0]
#  [130.0]
#  [270.0]
#  [30.0]
#  [107.0]
#  [331.0]
#  [78.0]
#  [301.0]
#  [111.0]
#  [124.0]
# ...

# %%
#Crear modelo de regresión lineal multiple
LR = LinearRegression()

# función fit es para entrenar el modelo, fitting o ajuste
LR = LR.fit(X, y)

# Testeo
Y_Predict = LR.predict(X) # Usa el modelo entrenado y para cada observacion predice un valor de Y, y lo almacena
error = np.sqrt(mean_squared_error(Y, Y_Predict)) # Saca el error entre el valor de Y original y las predicciones
r2 = LR.score(X, Y) # Calcula el R cuadrado

# Resultados del Testeo
print("El error es: ", error)
print("El valor de R cuadrado es: ", r2)
print("Los coeficientes de la regresión son: \n ", LR.coef_) #LR.coef_ para mostrar el valor de las betas del modelo de regresión
# Out:
# El error es:  21.819538679152526
# El valor de R cuadrado es:  0.9954323615919498
# Los coeficientes de la regresión son:
#   [[ 0.21551007 -0.40017767  0.84787796]]

# %% [markdown]
# __PRUEBA PREDECIR__

# %%
# Ingresar Inputs: 
Post_Hour = 3
Post_Weekday = 4
Total_Interactions = 100


print("Likes de la predicción: \n", LR.predict([[Post_Hour, Post_Weekday, Total_Interactions]]))
# Out:
# Likes de la predicción:
#  [[81.54288104]]
